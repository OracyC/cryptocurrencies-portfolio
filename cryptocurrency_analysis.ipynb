# %% [markdown]
# <a href="https://colab.research.google.com/github/OracyC/cryptocurrencies-portfolio/blob/master/cryptocurrency_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
files = "https://github.com/OracyC/cryptocurrencies-portfolio/raw/master/data.zip"
# !rm -rf * && pip install git+https://github.com/data-8/Gofer-Grader && wget $files && unzip -o data.zip
# Out:
# ...
#   Cloning https://github.com/data-8/Gofer-Grader to /tmp/pip-req-build-zfy9_t8l
#   Running command git clone -q https://github.com/data-8/Gofer-Grader /tmp/pip-req-build-zfy9_t8l
# ...
#   Created wheel for gofer-grader: filename=gofer_grader-1.0.9-cp36-none-any.whl size=10169 sha256=0bb681c00ec252513bca8077469ad3febb4631f93e34c58c998dd1d37a0341ff
#   Stored in directory: /tmp/pip-ephem-wheel-cache-6owbwaqs/wheels/9e/62/24/8563ae039051d6ba979557d1766bfebbda5dd08f8572e3e35d
# Successfully built gofer-grader
# ...
# --2019-12-11 00:23:56--  https://github.com/OracyC/cryptocurrencies-portfolio/raw/master/data.zip
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/OracyC/cryptocurrencies-portfolio/master/data.zip [following]
# ...

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('cryptocurrencies.csv')
data.head()
# Out:
#    Bitcoin  Ethereum   XRP  BitcoinCash  ...  Qtum  BitcoinGold  Lisk  Stellar
# 0    -0.03     -0.03 -0.03        -0.02  ...  0.01        -0.04 -0.05    -0.05
# 1    -0.02     -0.03 -0.01        -0.05  ... -0.01        -0.04 -0.02    -0.04
# 2     0.02      0.02  0.02         0.01  ...  0.00         0.04  0.02     0.01
# 3    -0.05     -0.05 -0.02        -0.12  ...  0.00        -0.05 -0.06    -0.07
# 4    -0.02     -0.03 -0.04        -0.11  ... -0.01        -0.04 -0.02    -0.07
#
# [5 rows x 21 columns]

# %%
data.Bitcoin
# Out:
# 0     -0.03
# 1     -0.02
# 2      0.02
# 3     -0.05
# 4     -0.02
#        ...
# 361    0.01
# 362    0.00
# 363    0.00
# 364   -0.02
# 365   -0.02
# Name: Bitcoin, Length: 366, dtype: float64

# %%
f,ax = plt.subplots(figsize=(20, 17))
sns.heatmap(data.corr(), annot=True, linewidths=0, fmt= '.3f',ax=ax)
plt.show()
